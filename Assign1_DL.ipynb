# %%
import numpy as np

# %%
class Perceptron:
    def __init__(self, lr=0.1, epochs=10):
        self.lr = lr
        self.epochs = epochs

    def fit(self, X, y):
        self.w = np.zeros(X.shape[1])
        self.b = 0

        for _ in range(self.epochs):
            for i in range(len(X)):
                z = np.dot(X[i], self.w) + self.b
                y_pred = 1 if z >= 0 else 0
                self.w += self.lr * (y[i] - y_pred) * X[i]
                self.b += self.lr * (y[i] - y_pred)

    def predict(self, X):
        return [1 if np.dot(x, self.w) + self.b >= 0 else 0 for x in X]

# %%
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

# %%
y_and = np.array([0,0,0,1])
p_and = Perceptron()
p_and.fit(X, y_and)
print("AND Gate Output:", p_and.predict(X))
# Out:
# AND Gate Output: [0, 0, 0, 1]

# %%
print("Weights:", p_and.w)
print("Bias:", p_and.b)
# Out:
# Weights: [0.2 0.1]
# Bias: -0.20000000000000004

# %%
y_or = np.array([0,1,1,1])
p_or = Perceptron()
p_or.fit(X, y_or)
print("OR Gate Output:", p_or.predict(X))
# Out:
# OR Gate Output: [0, 1, 1, 1]

# %%
y_nand = np.array([1,1,1,0])
p_nand = Perceptron()
p_nand.fit(X, y_nand)
print("NAND Gate Output:", p_nand.predict(X))
# Out:
# NAND Gate Output: [1, 1, 1, 0]

# %%
y_nor = np.array([1,0,0,0])
p_nor = Perceptron()
p_nor.fit(X, y_nor)
print("NOR Gate Output:", p_nor.predict(X))
# Out:
# NOR Gate Output: [1, 0, 0, 0]

# %%
y_xor = np.array([0,1,1,0])
p_xor = Perceptron()
p_xor.fit(X, y_xor)

print("XOR Output:", p_xor.predict(X))
print("Weights:", p_xor.w)
print("Bias:", p_xor.b)
# Out:
# XOR Output: [1, 1, 0, 0]
# Weights: [-0.1  0. ]
# Bias: 0.0

# %%
'''
Effect of Learning Rate (lr)

Learning rate controls how big each weight update is.
Small LR-Slow learning,more stable
Large LR-Faster learning,may overshoot optimal values'''
# Out:
# '\nEffect of Learning Rate (lr)\n\nLearning rate controls how big each weight update is.\nSmall LR-Slow learning,more stable\nLarge LR-Faster learning,may overshoot optimal values'

# %%
'''Why Same Code Learned Different Gates
Because each gate has a different data pattern.
Linearly separable gates
AND, OR, NAND, NOR
-A single straight line can separate classes
-Perceptron works'''
# Out:
# 'Why Same Code Learned Different Gates\nBecause each gate has a different data pattern.\nLinearly separable gates\nAND, OR, NAND, NOR\n-A single straight line can separate classes\n-Perceptron works'
